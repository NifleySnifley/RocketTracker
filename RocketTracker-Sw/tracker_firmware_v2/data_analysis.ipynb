# %%
import numpy as np
from matplotlib import pyplot as plt
import scipy as sp
from frccontrol import discretize_ab
# %matplotlib inline

# %%
data = np.genfromtxt('C:/Users/finns/Downloads/sensordata', delimiter=',')[97000:, :]

# %%
accel = data[:,1]
alt = data[:, 0]

# %%
np.std(alt)**2
# Out:
# 0.06322944764207783

# %%
np.std(accel[:2400])**2
# Out:
# 1.3940354099852605e-05

# %%
A = np.array([[0,1],[0,0]])
B = np.array([[0.0],[1.0]])
Adis, Bdis = discretize_ab(A, B,1.0/256)

# %%
Adis,Bdis
# Out:
# (array([[1.        , 0.00390625],
#         [0.        , 1.        ]]),
#  array([[7.62939453e-06],
#         [3.90625000e-03]]))

# %%
dout = np.genfromtxt(
    'C:/Users/finns/Downloads/kalmandataout', delimiter=',')[80000:, :]

# %%
plt.plot(dout[19000:,2])
plt.plot(dout[19000:, 0])
